# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# <h1> My Jupyter Notebook on IBM Watson Studio <h1>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# <b> Viktorija Hajduk </b>
#
# Current occupation: Data Analyst

# %% [markdown]
# <i> I am interested in data science because I want to advance in my career </i>

# %% [markdown]
# <h3> Simple calculation using two variables </h3>

# %%
a = 4
b = 2
print(a*b)
# Out:
# 8

# %% [markdown]
# <table>
#   <tr>
#     <th>Number 1</th>
#     <th>Number 2</th>
#     <th>Sum</th>
#   </tr>
#   <tr>
#     <td>3</td>
#     <td>5</td>
#     <td>8</td>
#   </tr>
#   <tr>
#     <td>1</td>
#     <td>6</td>
#     <td>7</td>
#   </tr>
#   <tr>
#     <td>4</td>
#     <td>11</td>
#     <td>15</td>
#   </tr>
# </table>
#
# <h3> Results </h3>
# <ul>
#   <li>8</li>
#   <li>7</li>
#   <li>15</li>
# </ul>
#
# More on HTML here <a href="https://www.w3schools.com/html/html_links.asp">W3Schools</a>
